# %% [markdown]
# lib res

# %%
import itertools
import numpy as np
class RESeries:
    """Container for standard E-series values as NumPy arrays"""
    
    E6 = np.array([1.0, 1.5, 2.2, 3.3, 4.7, 6.8])
    
    E12 = np.array([1.0, 1.2, 1.5, 1.8, 2.2, 2.7, 3.3, 3.9, 4.7, 5.6, 6.8, 8.2])
    
    E24 = np.array([1.0, 1.1, 1.2, 1.3, 1.5, 1.6, 1.8, 2.0, 2.2, 2.4, 2.7, 3.0,
                    3.3, 3.6, 3.9, 4.3, 4.7, 5.1, 5.6, 6.2, 6.8, 7.5, 8.2, 9.1])
    
    E48 = np.array([1.00, 1.05, 1.10, 1.15, 1.21, 1.27, 1.33, 1.40, 1.47, 1.54,
                    1.62, 1.69, 1.78, 1.87, 1.96, 2.05, 2.15, 2.26, 2.37, 2.49,
                    2.61, 2.74, 2.87, 3.01, 3.16, 3.32, 3.48, 3.65, 3.83, 4.02,
                    4.22, 4.42, 4.64, 4.87, 5.11, 5.36, 5.62, 5.90, 6.19, 6.49,
                    6.81, 7.15, 7.50, 7.87, 8.25, 8.66, 9.09, 9.53])
    
    E96 = np.array([1.00, 1.02, 1.05, 1.07, 1.10, 1.13, 1.15, 1.18, 1.21, 1.24,
                    1.27, 1.30, 1.33, 1.37, 1.40, 1.43, 1.47, 1.50, 1.54, 1.58,
                    1.62, 1.65, 1.69, 1.74, 1.78, 1.82, 1.87, 1.91, 1.96, 2.00,
                    2.05, 2.10, 2.15, 2.21, 2.26, 2.32, 2.37, 2.43, 2.49, 2.55,
                    2.61, 2.67, 2.74, 2.80, 2.87, 2.94, 3.01, 3.09, 3.16, 3.24,
                    3.32, 3.40, 3.48, 3.57, 3.65, 3.74, 3.83, 3.92, 4.02, 4.12,
                    4.22, 4.32, 4.42, 4.53, 4.64, 4.75, 4.87, 4.99, 5.11, 5.23,
                    5.36, 5.49, 5.62, 5.76, 5.90, 5.97, 6.04, 6.12, 6.19, 6.26,
                    6.34, 6.42, 6.49, 6.57, 6.65, 6.73, 6.81, 6.90, 6.98, 7.06,
                    7.15, 7.23, 7.32, 7.41, 7.50, 7.59, 7.68, 7.77, 7.87, 7.96,
                    8.06, 8.16, 8.25, 8.35, 8.45, 8.56, 8.66, 8.76, 8.87, 8.98,
                    9.09, 9.20, 9.31, 9.42, 9.53, 9.65, 9.76, 9.88])
    
    E192 = np.array([1.00, 1.01, 1.02, 1.04, 1.05, 1.06, 1.07, 1.09, 1.10, 1.11,
                     1.13, 1.14, 1.15, 1.17, 1.18, 1.20, 1.21, 1.23, 1.24, 1.26,
                     1.27, 1.29, 1.30, 1.32, 1.33, 1.35, 1.37, 1.38, 1.40, 1.42,
                     1.43, 1.45, 1.47, 1.49, 1.50, 1.52, 1.54, 1.56, 1.58, 1.60,
                     1.62, 1.64, 1.65, 1.67, 1.69, 1.72, 1.74, 1.76, 1.78, 1.80,
                     1.82, 1.84, 1.87, 1.89, 1.91, 1.93, 1.96, 1.98, 2.00, 2.03,
                     2.05, 2.08, 2.10, 2.13, 2.15, 2.18, 2.21, 2.23, 2.26, 2.29,
                     2.32, 2.34, 2.37, 2.40, 2.43, 2.46, 2.49, 2.52, 2.55, 2.58,
                     2.61, 2.64, 2.67, 2.71, 2.74, 2.77, 2.80, 2.84, 2.87, 2.91,
                     2.94, 2.98, 3.01, 3.05, 3.09, 3.12, 3.16, 3.20, 3.24, 3.28,
                     3.32, 3.36, 3.40, 3.44, 3.48, 3.52, 3.57, 3.61, 3.65, 3.70,
                     3.74, 3.79, 3.83, 3.88, 3.92, 3.97, 4.02, 4.07, 4.12, 4.17,
                     4.22, 4.27, 4.32, 4.37, 4.42, 4.48, 4.53, 4.59, 4.64, 4.70,
                     4.75, 4.81, 4.87, 4.93, 4.99, 5.05, 5.11, 5.17, 5.23, 5.30,
                     5.36, 5.42, 5.49, 5.56, 5.62, 5.69, 5.76, 5.83, 5.90, 5.97,
                     6.04, 6.12, 6.19, 6.26, 6.34, 6.42, 6.49, 6.57, 6.65, 6.73,
                     6.81, 6.90, 6.98, 7.06, 7.15, 7.23, 7.32, 7.41, 7.50, 7.59,
                     7.68, 7.77, 7.87, 7.96, 8.06, 8.16, 8.25, 8.35, 8.45, 8.56,
                     8.66, 8.76, 8.87, 8.98, 9.09, 9.20, 9.31, 9.42, 9.53, 9.65,
                     9.76, 9.88])

e6 = tuple(RESeries.E6)
e12 = tuple(RESeries.E12)
e24 = tuple(RESeries.E24)
e48 = tuple(RESeries.E48)
e96 = tuple(RESeries.E96)
e192 = tuple(RESeries.E192)

#Get a single range of resistors of a given sequence,e.g. for 1k to <10k use multiplicator = 1000.  
def resistor_range(multiplicator, sequence=e96):
    
    # Multiply ndarrays directly for performance
    if isinstance(sequence, np.ndarray):
        return sequence * multiplicator
    # Otherwise, use list comprehension
    return [r * multiplicator for r in sequence]

#Get a list of all standard resistor values from 100mOhm up to 976 MΩ in Ω
def standard_resistors(minExp=-1, maxExp=9, sequence=e96):
    exponents = itertools.islice(itertools.count(minExp, 1), 0, maxExp - minExp)
    multiplicators = [10 ** x for x in exponents]
    return itertools.chain(*(resistor_range(r, sequence=sequence) for r in multiplicators))

#Find the closest resistor
def nearest_resistor(value, sequence=e96):    
    return min(standard_resistors(sequence=sequence), key=lambda r: abs(value - r))

#Find the next higher resistor
def next_higher_resistor(value, sequence=e96):
    return min((r for r in standard_resistors(sequence=sequence) if r > value), default=None)


#Find the next lower standard resistor value
def next_lower_resistor(value, sequence=e96):
    return max((r for r in standard_resistors(sequence=sequence) if r < value), default=None)

# %% [markdown]
# set temp limits for wich to optimise

# %%
def _cvd_pos(t, R0, A, B):
    return R0 * (1 + A * t + B * t**2)

def _cvd_neg(t, R0, A, B, C):
    return R0 * (1 + A * t + B * t**2 + C * (t - 100) * t**3)

def temperature2resistance(t, R0=100.0, A=3.9083e-3, B=-5.775e-7, C=-4.183e-12):
    """Convert temperature to resistance for platinum resistors.

    Converts temperature to resistance for platinum resistors by the Callendar
    Van Dusen equations.

    Arguments
    ---------
    t : float or 1darray
        Temperature to convert to resistance.
    R0 : float, optional
        Resistance at 0C, for example 100ohm for Pt100 or 1000ohm for Pt1000.
    A,B,C : float, optional
        Coefficients for platinum resistors, see e.g. IEC60751.

    Returns
    -------
    1darray
        Resistance values for corresponding temperature.

    Raises
    ------
    ValueError
        If the temperature is out of bounds, i.e (T<-200C) or (T>850C) equation.
    """
    t = np.asarray(t, dtype=float)
    if np.any(t<-200) or np.any(t>850):
        raise ValueError(
            "Resistance only defined for temperatures between -200C and 850C."
        )
    R = np.piecewise(
        t,
        [t < 0.0, t >= 0.0],
        [lambda x: _cvd_neg(x, R0, A, B, C), lambda x: _cvd_pos(x, R0, A, B)],
    )
    if R.size == 1:
        R = float(R)
    return R


print("set temperature scale for optimisation")
print("input lowest temp in C")
Tmin= float(input())
Rmin= temperature2resistance(Tmin, 1000.0)#,1000.0)# ,3.9083e-3, -5.775e-7, -4.183e-12)
print("input highest temp in C")
Tmax= float(input())
Rmax= temperature2resistance(Tmax, 1000.0)#  ,3.9083e-3, -5.775e-7, -4.183e-12)
print("set Rdivider in Ohm if using")
RIlim= float(input())
# Out:
# set temperature scale for optimisation
# input lowest temp in C
#  -10
# input highest temp in C
#  65
# set Rdivider in Ohm if using
#  6800

# %% [markdown]
# determine b and m then select the right formula

# %%
print("set Vref in V")
Vref= float(input())
Iselfheat=Vref/(RIlim+Rmin)
VinFS = Vref*Rmax/(RIlim+Rmax)
VinZS = Vref*Rmin/(RIlim+Rmin)

print("fullscale Voltage = ",VinFS," V")
print("zeroscale Voltage = ",VinZS," V")
print("the max current through the RTD = " , Iselfheat, " A")
print("be carefull for self heating, Iselfheat should not be larger the 0.0005 A")

print("Set fullscale ouput voltage in V")
VoutFS= float(input())
print("Set zeroscale ouput voltage in V")
VoutZS= float(input())

m=(VoutFS-VoutZS)/(VinFS-VinZS)
b=VoutZS-m*VinZS

print("m = ", m,"\n")
print("b = ", b,"\n")
# Out:
# set Vref in V
#  3.3
# fullscale Voltage =  0.5129761514080514  V
# zeroscale Voltage =  0.4085674140482736  V
# the max current through the RTD =  0.00042521067440466566  A
# be carefull for self heating, Iselfheat should not be larger the 0.0005 A
# Set fullscale ouput voltage in V
#  3
# Set zeroscale ouput voltage in V
#  1
# m =  19.155484977356654
#
# b =  -6.826306962039161

# %% [markdown]
# now calculate the resistor parameters

# %%
if(m>0 and b>0):
    print("m>0 AND b>0")
    print("page 2 section 3 \n")
    print("choose R1 in Ohm (check datasheet opamp look for operating current to check scale)")
    R1=float(input())
    R2 =Vref*R1*m/b
    print("R2 = ",R2," Ohm")
    print("choose Rf in Ohm check datasheet opamp look for operating current to check scale)")
    Rf=float(input())
    Rg= R2*Rf/(m*(R1+R2)-R2)
    print("Rg = ",Rg," Ohm")
    print("SEE TEXT FOR FURTHER INPUT TUNING")
    
if(m>0 and b<0):
    print("m>0 AND b<0")
    print("page 3 section 4 \n")
    print("choose Rf in Ohm (check datasheet opamp look for operating current to check scale)")
    Rf=float(input())
    Rg=nearest_resistor(Rf/(m-1))
    Rg2=Rg/10
    Rg1=nearest_resistor(Rg-Rg2)
    print("Rg = ",Rg," Ohm")
    print("Rg2 = ",Rg2," Ohm")
    print("Rg1 = ",Rg1," Ohm")
    VrefACC = (abs(b)*Rg1)/(Rg1+Rf)
    print("Vref\' = ",VrefACC," V")
    R1 = nearest_resistor((Rg2*(Vref-VrefACC))/(VrefACC))
    print("R1 = ",R1," Ohm")
    print("SEE TEXT FOR FURTHER INPUT TUNING")
    
if(m<0 and b>0):
    print("m<0 AND b<0")
    print("page 5 section 5 \n")
    print("choose Rf in Ohm (check datasheet opamp look for operating current to check scale)")
    Rf=float(input())
    Rg=Rf/(abs(m))
    print("Rg = ",Rg," Ohm")
    print("choose R2 in Ohm (chose same magnitude as Rf)")
    R2=float(input())
    R1=b*R2*Rg/(Vref*(Rf+Rg)-b*Rg)
    print("R1 = ",R1," Ohm")
    print("SEE TEXT SECTION 7 FOR FURTHER TUNING")
if(m<0 and b<0):
    print("m<0 AND b>0")
    print("page 5 section 6 \n")
    print("choose Rf in Ohm (check datasheet opamp look for operating current to check scale)")
    Rf=float(input())
    Rg1=Rf/(abs(m))
    Rg2=Vref*Rf/(abs(m))
    print("Rg1 = ",Rg1," Ohm")
    print("Rg2 = ",Rg2," Ohm")
# Out:
# m>0 AND b<0
# page 3 section 4
#
# choose Rf in Ohm (check datasheet opamp look for operating current to check scale)
#  68000
# Rg =  3740.0  Ohm
# Rg2 =  374.0  Ohm
# Rg1 =  3400.0  Ohm
# Vref' =  0.3250622362875791  V
# R1 =  3400.0  Ohm
# SEE TEXT FOR FURTHER INPUT TUNING
